# %% [markdown]
# # Evaluation of Jittering on NuScenes and EDGARScenes Data

# %% [markdown]
# ## PRC Curves

# %%
from utils import plot_PRC_curve

# %% [markdown]
# ### NuScenes

# %%
plot_PRC_curve('/workspaces/Poly-MOT/paper/mWS2_eSS1/', aggregate_vehicles=False)

# %% [markdown]
# ### EdgarScenes

# %%
plot_PRC_curve('/workspaces/Poly-MOT/paper/edgarscenes_jitter/', aggregate_vehicles=False, data='edgar')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plot_PRC_curve('/workspaces/Poly-MOT/paper/edgarscenes_jitter/', aggregate_vehicles=False)
#
# File /workspaces/Poly-MOT/jittering_module/utils.py:47, in plot_PRC_curve(data_dir, aggregate_vehicles)
#      45 prediction_arr = df['mov_Pred'][mask].to_numpy()
#      46 GT_arr = df['mov_GT'][mask].to_numpy()
# ---> 47 prec, rec, threshold = sk.precision_recall_curve(GT_arr, prediction_arr, pos_label='moving')
#      48 sk.PrecisionRecallDisplay.from_predictions(GT_arr, prediction_arr, pos_label='moving', ax=axes[plot_idx], plot_chance_level=True)
#      49 ax2 = axes[plot_idx].twinx()
#
# File /usr/local/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
# ...
